# %%
import pandas as pd

# %%
animal_all = pd.read_csv('animal_all_utf8.txt', encoding='utf-8')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
animal_all[animal_all['weight'] == '0.66/0.54(Kg)']
# Out:
#             age                     careAddr     careNm colorCd  happenDt  \
# 20486  2018(년생)  전라남도 광양시 사동로 70 (중동) 1층/ 2층  광양동물메디컬센터      황색  20180531
#
#        happenPlace   kindCd neuterYn  noticeEdt          noticeNo  noticeSdt  \
# 20486  다압면 섬진마을 주변  [개] 믹스견        N   20180611  전남-광양-2018-00154   20180601
#
#                                                  popfile processState sexCd  \
# 20486  http://www.animal.go.kr/files/shelter/2018/05/...       종료(입양)     M
#
#          specialMark         weight Unnamed: 16
# 20486  수컷 2마리 ( 2주 )  0.66/0.54(Kg)         NaN

# %%
animal_all['happenPlace'].value_counts().head()
# Out:
# 구청 당직실     612
# 구청당직실      414
# 부평구청당직실    395
# 성남소방서      332
# 남구청        229
# Name: happenPlace, dtype: int64

# %%
for index, contents in enumerate(animal_all['age']):
    if contents == '3(년생)':
        animal_all['age'].iloc[index] = '2015'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
animal_all['age'].value_counts()
# Out:
# 2017    46281
# 2018    24919
# 2016    20303
# 2015    19674
# 2014    13700
# 2013     8153
# 2012     6678
# 2011     3128
# 2010     2790
# 2007     2213
# 2009     1941
# 2008     1569
# 2005      480
# 2006      367
# 2004      250
# 2003      221
# 2002      213
# 2001       40
#            15
# 2000       12
# 1999        5
# 1993        3
# 1998        3
# 1997        2
# 1988        2
# 1992        1
# 1995        1
# Name: age, dtype: int64

# %%
for index, contents in enumerate(animal_all['age']):
    animal_all['age'].iloc[index] = contents.split('(')[0]
    
#     if(contents == '0(년생)'):
#         animal_all['age'].iloc[index] = ''
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
delete_index = animal_all[animal_all['age'] == ''].index

# %%
animal_all = animal_all.drop(delete_index)

# %%
animal_all.head()
# Out:
#         age                                           careAddr      careNm  \
# 0  2017(년생)  충청남도 천안시 동남구 목천읍 학수소사길 132 (목천읍) [입양센터:서북구 천안천...  천안시유기동물보호소
# 1  2015(년생)  충청남도 천안시 동남구 목천읍 학수소사길 132 (목천읍) [입양센터:서북구 천안천...  천안시유기동물보호소
# 2  2015(년생)          경상남도 창녕군 영산면 로터리길 22-1 (영산면) 고암면 억만리 28-1  창녕 유기동물보호소
# 3  2013(년생)          경상남도 창녕군 영산면 로터리길 22-1 (영산면) 고암면 억만리 28-1  창녕 유기동물보호소
# 4  2018(년생)          경상남도 창녕군 영산면 로터리길 22-1 (영산면) 고암면 억만리 28-1  창녕 유기동물보호소
#
#   colorCd  happenDt   happenPlace     kindCd neuterYn  noticeEdt  \
# 0     올블랙  20170703  동남구 신방동 1243  [고양이] 고양이        N   20700713
# 1      흰검  20170722        집안에서발견   [개] 슈나우져        N   20470801
# 2   검정+흰색  20180220        도천면 일리    [개] 믹스견        N   20200304
# 3      흰색  20180220        창녕 소방서    [개] 진도견        N   20200304
# 4      노랑  20180220   이방면 옥천리 잠어실    [개] 믹스견        N   20200304
#
#            noticeNo  noticeSdt  \
# 0  충남-천안-2017-00853   20170704
# 1  충남-천안-2017-00941   20170723
# ...

# %%
age_done = animal_all

# %%
age_done.to_csv('age_done.csv')

# %%
for i in range(1, 1000):
    if age_done['careAddr'][i].split()[0][-1] == '시':
        print(age_done['careAddr'][i].split()[0], age_done['careAddr'][i].split()[1])
# Out:
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 대전광역시 유성구
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 남구
# 울산광역시 울주군
# 울산광역시 울주군
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 광주광역시 북구
# 대구광역시 달성군
# 대구광역시 동구
# 대구광역시 서구
# 대구광역시 서구
# 대구광역시 서구
# 부산광역시 강서구
# 부산광역시 강서구
# 부산광역시 연제구
# 부산광역시 연제구
# 부산광역시 해운대구
# 부산광역시 해운대구
# 부산광역시 해운대구
# 서울특별시 강동구
# 서울특별시 관악구
# 서울특별시 양천구
# 서울특별시 마포구
# 대전광역시 유성구
# 대전광역시 유성구
# 인천광역시 부평구
# 인천광역시 부평구
# 인천광역시 부평구
# 인천광역시 계양구
# 부산광역시 강서구
# 부산광역시 강서구
# 부산광역시 해운대구
# 부산광역시 해운대구
# 부산광역시 해운대구
# 부산광역시 강서구
# 서울특별시 관악구
# 부산광역시 강서구
# 부산광역시 강서구
# 부산광역시 강서구
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 울산광역시 울주군
# 광주광역시 북구
# 인천광역시 서구
# 인천광역시 서구
# 인천광역시 계양구
# 인천광역시 계양구
# 인천광역시 계양구
# 인천광역시 중구
# 인천광역시 중구
# 인천광역시 중구
# 인천광역시 중구
# ...

# %%
for i in range(1, 1000):
    if age_done['careAddr'][i].split()[0][-1] == '도':
        print(age_done['careAddr'][i].split()[0], age_done['careAddr'][i].split()[1], age_done['careAddr'][i].split()[2])
# Out:
# 충청남도 천안시 동남구
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경기도 안산시 상록구
# 경기도 안산시 상록구
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 충청남도 천안시 동남구
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# 경상남도 창녕군 영산면
# ...

# %%
age_change_idx = animal_all[animal_all['age'] == ' (년생)']['age'].index

# %%
age_change_idx = animal_all[animal_all['age'] == '#NAME?']['age'].index

# %%
animal_all.iloc[age_change_idx]['age'].replace(' (년생)', 'a')
# Out:
# 51615    #NAME?
# Name: age, dtype: object

# %%
animal_all.iloc[age_change_idx]
# Out:
# Empty DataFrame
# Columns: [age, careAddr, careNm, colorCd, happenDt, happenPlace, kindCd, neuterYn, noticeEdt, noticeNo, noticeSdt, popfile, processState, sexCd, specialMark, weight, Unnamed: 16]
# Index: []
