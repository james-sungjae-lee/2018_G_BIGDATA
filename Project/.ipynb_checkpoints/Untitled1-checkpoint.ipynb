# %%
import pandas as pd

# %%
pre2 = pd.read_csv('pre1.txt')

# %%
pre2 = pre2.drop(['Unnamed: 0'], axis = 1)

# %%
pre2.rename(columns = {'happenYear':'hapY', 'happenMonth':'hapM', 'happenDay':'hapD'}, inplace = True)

# %%
pre2.head()
# Out:
#     age      careNm colorCd neuterYn  noticeEdt  noticeSdt processState sexCd  \
# 0  2017  천안시유기동물보호소     올블랙        N   20700713   20170704       종료(입양)     M
# 1  2015  천안시유기동물보호소      흰검        N   20470801   20170723          보호중     F
# 2  2015  창녕 유기동물보호소   검정+흰색        N   20200304   20180221      종료(안락사)     F
# 3  2013  창녕 유기동물보호소      흰색        N   20200304   20180221       종료(입양)     M
# 4  2018  창녕 유기동물보호소      노랑        N   20200304   20180221      종료(자연사)     F
#
#               specialMark kind care1 care2 care3 care4  noticeNo  noticeRange  \
# 0  (716) 쓰러져있는 아기고양이를 신고함  고양이  충청남도   천안시   동남구   목천읍       853       530009
# 1        (804) 장기간 돌아다녀신고    개  충청남도   천안시   동남구   목천읍       941       300078
# 2                      없음    개  경상남도   창녕군   영산면  로터리길       182        20083
# 3                      없음    개  경상남도   창녕군   영산면  로터리길       181        20083
# 4                   새끼5마리    개  경상남도   창녕군   영산면  로터리길       177        20083
#
#   weight  hapY  hapM  hapD
# 0    0.9  2017     7     3
# 1    4.2  2017     7    22
# 2     20  2018     2    20
# 3     25  2018     2    20
# 4    0.2  2018     2    20

# %%
pre2.processState.value_counts()
# Out:
# 종료(입양)     44833
# 종료(자연사)    38292
# 종료(안락사)    27671
# 종료(반환)     21720
# 보호중        16230
# 종료(기증)      2837
# 종료(방사)      1248
# 종료(미포획)      118
# Name: processState, dtype: int64
