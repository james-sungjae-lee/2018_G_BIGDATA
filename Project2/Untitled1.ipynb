# %%
import pandas as pd

# %%
data = pd.read_csv('pre_done.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   age      careNm color neuter    state sexCd kind care1 care2  \
# 0           0  2017  천안시유기동물보호소     B      N   종료(입양)     M  고양이  충청남도   천안시
# 1           1  2015  천안시유기동물보호소     M      N      보호중     F    개  충청남도   천안시
# 2           2  2015  창녕 유기동물보호소     M      N  종료(안락사)     F    개  경상남도   창녕군
# 3           3  2013  창녕 유기동물보호소     W      N   종료(입양)     M    개  경상남도   창녕군
# 4           4  2018  창녕 유기동물보호소     Y      N  종료(자연사)     F    개  경상남도   창녕군
#
#   care3  noticeNo  weight  hapY  hapM  hapD    sad   good   safe   item
# 0   동남구       853     0.9  2017     7     3  False  False  False  False
# 1   동남구       941     4.2  2017     7    22  False  False  False  False
# 2   영산면       182    20.0  2018     2    20  False  False  False  False
# 3   영산면       181    25.0  2018     2    20  False  False  False  False
# 4   영산면       177     0.2  2018     2    20  False  False  False  False

# %%
data.groupby(['care1'])['state'].count()
# Out:
# care1
# 강원도         7284
# 경기도        44088
# 경상남도       12134
# 경상북도        8375
# 광주광역시       5440
# 대구광역시       6718
# 대전광역시       7471
# 부산광역시      13347
# 서울특별시       4121
# 세종특별자치시      547
# 울산광역시       4451
# 인천광역시       9833
# 전라남도        7343
# 전라북도        7623
# 제주특별자치도        8
# 충청남도        9204
# 충청북도        4962
# Name: state, dtype: int64
