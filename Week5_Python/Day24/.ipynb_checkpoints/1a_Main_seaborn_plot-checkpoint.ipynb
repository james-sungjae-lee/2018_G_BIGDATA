# %% [markdown]
# ## Seaborn Basic
# ## 20180726
# ## Sungjae Lee

# %% [markdown]
# ## 분포 플롯

# %% [markdown]
# 러그(rug) 데이터 위치를 x축 위에 작은 선분으로 나타내어 실제 데이터 분포를 보여준다.

# %%
import numpy as np
import seaborn as sns

# %%
np.random.seed(0)
x = np.random.randn(100)

# %%
sns.rugplot(x);
# 빈도에 대한 보조지표로 활용 가능하다

# %%
sns.kdeplot(x);

# %%
sns.distplot(x, kde=True, rug=True);
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tips = sns.load_dataset("tips")
sns.jointplot(x="total_bill", y="tip", data=tips);
tips.head()
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/sungjae/y36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris = sns.load_dataset("iris")
sns.jointplot("sepal_width", "petal_length", data=iris, kind="kde", space=0, color="g");
# kind = 'kde' 의 경우 등고선으로 나타나게 된다.

# %% [markdown]
# ## 회귀 분석 플롯

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# `residplot`은 잔차항(residual)를 스캐터 플롯으로 그린다.

# %%
sns.residplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# `lmplot` 명령을 사용하면 여러가지 회귀 분석 결과를 하나의 그림에 보일 수 있다.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips);

# %% [markdown]
# ## 카테고리 플롯

# %% [markdown]
# `barplot` 은 기본적인 바 차트를 생성한다.

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips);

# %% [markdown]
# `countplot`은 카테고리가 다른 데이터 갯수를 시각화한다.

# %%
titanic = sns.load_dataset("titanic")
sns.countplot(x="class", hue="who", data=titanic);

# %% [markdown]
# `boxplot`과 `pointplot`은 카테고리 인자에 따라 분포의 특성이 어떻게 바뀌는지를 보여준다.

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips, dodge=True);

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="muted");

# %%
sns.violinplot(x="day", y="total_bill", hue="sex",
               data=tips, palette="Set2", split=True,
               scale="count", inner="quartile");

# %%
sns.stripplot(x="day", y="total_bill", hue="smoker",
              data=tips, jitter=True,
              palette="Set2", split=True);
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/seaborn/categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
sns.stripplot(x="tip", y="day", data=tips, jitter=True, color=".3");

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="white", edgecolor="gray");

# %% [markdown]
# ## 행렬 플롯

# %% [markdown]
# `heatmap` 명령은 카테고리 값에 따른 자료의 수를 세고 이를 matplotlib 패키지의 `imshow`와 유사한 형태로 보여준다.

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.heatmap(flights, annot=True, fmt="d");

# %%
print(sns.get_dataset_names())
sns.load_dataset('flights').head()
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/sungjae/y36/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'iris', 'mpg', 'planets', 'tips', 'titanic']
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121
