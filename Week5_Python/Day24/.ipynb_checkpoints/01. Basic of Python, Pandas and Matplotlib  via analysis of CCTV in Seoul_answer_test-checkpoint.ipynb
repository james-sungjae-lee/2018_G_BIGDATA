# %% [markdown]
# ## Seoul CCTV Data Analysis
# ## 20180726
# ## Sungjae Lee

# %% [markdown]
# # 서울시 구별 CCTV 현황 분석하기
#
#
#
# * 서울시 각 구별 CCTV수를 파악하고, 인구대비 CCTV 비율을 파악해서 순위 비교
# * 인구대비 CCTV의 평균치를 확인하고 그로부터 CCTV가 과하게 부족한 구를 확인

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
CCTV_Seoul = pd.read_csv('01. CCTV_in_Seoul.csv',  encoding='utf-8')
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
#column명 출력

CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
#값만 출력

CCTV_Seoul.values
# Out:
# array([['강남구', 2780, 1292, 430, 584, 932],
#        ['강동구', 773, 379, 99, 155, 377],
#        ['강북구', 748, 369, 120, 138, 204],
#        ['강서구', 884, 388, 258, 184, 81],
#        ['관악구', 1496, 846, 260, 390, 613],
#        ['광진구', 707, 573, 78, 53, 174],
#        ['구로구', 1561, 1142, 173, 246, 323],
#        ['금천구', 1015, 674, 51, 269, 354],
#        ['노원구', 1265, 542, 57, 451, 516],
#        ['도봉구', 485, 238, 159, 42, 386],
#        ['동대문구', 1294, 1070, 23, 198, 579],
#        ['동작구', 1091, 544, 341, 103, 314],
#        ['마포구', 574, 314, 118, 169, 379],
#        ['서대문구', 962, 844, 50, 68, 292],
#        ['서초구', 1930, 1406, 157, 336, 398],
#        ['성동구', 1062, 730, 91, 241, 265],
#        ['성북구', 1464, 1009, 78, 360, 204],
#        ['송파구', 618, 529, 21, 68, 463],
#        ['양천구', 2034, 1843, 142, 30, 467],
#        ['영등포구', 904, 495, 214, 195, 373],
#        ['용산구', 1624, 1368, 218, 112, 398],
#        ['은평구', 1873, 1138, 224, 278, 468],
#        ['종로구', 1002, 464, 314, 211, 630],
# ...

# %%
# 칼럼명 :'기관명' -> '구별' 수정

CCTV_Seoul=CCTV_Seoul.rename(columns = {'기관명':'구별'})
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %% [markdown]
# ##  엑셀파일 읽기 - 서울시 인구현황

# %%
pop_Seoul = pd.read_excel('01. population_in_Seoul.xls',  encoding='utf-8')
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764

# %%
pop_Seoul = pd.read_excel('01. population_in_Seoul.xls', 
                          header = 2,
                          usecols = 'B, D, G, J, N',
                          encoding='utf-8')
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 칼럼명 수정
pop_Seoul.columns = ['구별', '인구수', '한국인', '외국인', '고령자']
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %% [markdown]
# #  CCTV 데이터 파악하기

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
# 소계를 기준으로 오름차순 정렬

CCTV_Seoul.sort_values('소계').head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  485        238    159     42    386
# 12  마포구  574        314    118    169    379
# 17  송파구  618        529     21     68    463
# 24  중랑구  660        509    121    177    109
# 23   중구  671        413    190     72    348

# %%
# 소계를 중심으로 내림차순 정렬
CCTV_Seoul.sort_values('소계', ascending = False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
# 16년 증가율 구하기
CCTV_Seoul['16년 증가율'] = CCTV_Seoul['2016년'] / CCTV_Seoul['2015년'] * 100
CCTV_Seoul.sort_values('16년 증가율', ascending = False).head()
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년      16년 증가율
# 18   양천구  2034       1843    142     30    467  1556.666667
# 9    도봉구   485        238    159     42    386   919.047619
# 17   송파구   618        529     21     68    463   680.882353
# 23    중구   671        413    190     72    348   483.333333
# 13  서대문구   962        844     50     68    292   429.411765

# %% [markdown]
# #  서울시 인구 데이터 파악하기

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 첫번째 row 삭제, 원본데이터 반영

pop_Seoul = pop_Seoul[1:]
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
# 구별 칼럼의 unique값 구하기

print(pop_Seoul['구별'].unique())
print(pop_Seoul['구별'].nunique())
# Out:
# ['종로구' '중구' '용산구' '성동구' '광진구' '동대문구' '중랑구' '성북구' '강북구' '도봉구' '노원구' '은평구'
#  '서대문구' '마포구' '양천구' '강서구' '구로구' '금천구' '영등포구' '동작구' '관악구' '서초구' '강남구' '송파구'
#  '강동구' nan]
# 25

# %%
# '구별'칼럼에서 결측치가 있는 row구하기

pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
# '구별'칼럼에서 결측치가 있는 row 삭제하기
pop_Seoul = pop_Seoul.drop(pop_Seoul.index[25])
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
# 구별 외국인 비율 / 고령자 비율 구하기

pop_Seoul['외국인비율'] = (pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100)
pop_Seoul['고령자비율'] = (pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100)
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849

# %%
# 인구수 기준 내림차순 정렬

pop_Seoul.sort_values('인구수', ascending = False).head()
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 16  강서구  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 23  강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 11  노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 21  관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291

# %%
# 외국인수 기준 내림차순 정렬

pop_Seoul.sort_values('외국인', ascending = False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 21   관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291
# 6   동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322

# %%
pop_Seoul.sort_values(by='외국인비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %%
pop_Seoul.sort_values(by='고령자', ascending=False).head(5)
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 16  강서구  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 12  은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 11  노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 21  관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291

# %%
pop_Seoul.sort_values(by='고령자비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797

# %% [markdown]
# #  CCTV 데이터와 인구 데이터 합치고 분석하기

# %%
# '구별'칼럼을 기준으로 cctv데이터와 인구데이터를 합하기

m_Seoul = pd.merge(CCTV_Seoul, pop_Seoul, on = '구별')
m_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년     16년 증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  159.589041  570500.0  565550.0
# 1  강동구   773        379     99    155    377  243.225806  453233.0  449019.0
# 2  강북구   748        369    120    138    204  147.826087  330192.0  326686.0
# 3  강서구   884        388    258    184     81   44.021739  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  157.179487  525515.0  507203.0
#
#        외국인      고령자     외국인비율      고령자비율
# 0   4950.0  63167.0  0.867660  11.072217
# 1   4214.0  54622.0  0.929765  12.051638
# 2   3506.0  54813.0  1.061806  16.600342
# 3   6524.0  72548.0  1.080540  12.015794
# 4  18312.0  68082.0  3.484582  12.955291

# %%
# 2013년도 이전, 2014년, 2015년, 2016년 칼럼 삭제

m_Seoul = m_Seoul.drop(['2013년도 이전', '2014년', '2015년', '2016년'], axis = 1)
m_Seoul.head()
# Out:
#     구별    소계     16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  243.225806  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  147.826087  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884   44.021739  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  157.179487  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율
# 0  11.072217
# 1  12.051638
# 2  16.600342
# 3  12.015794
# 4  12.955291

# %%
# '구별' 칼럼을 인덱스로 설정

m_Seoul.index = m_Seoul['구별']
del m_Seoul['구별']
m_Seoul.head()
# Out:
#        소계     16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  243.225806  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  147.826087  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884   44.021739  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  157.179487  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
# 고령자 비율과 소계의 상관계수

m_Seoul[['고령자비율', '소계']].corr()
# Out:
#           고령자비율        소계
# 고령자비율  1.000000 -0.280786
# 소계    -0.280786  1.000000

# %%
np.corrcoef(m_Seoul['고령자비율'], m_Seoul['소계'])
# Out:
# array([[ 1.        , -0.28078554],
#        [-0.28078554,  1.        ]])

# %%
# 외국인 비율과 소계의 상관계수

m_Seoul[['외국인비율', '소계']].corr()
# Out:
#           외국인비율        소계
# 외국인비율  1.000000 -0.136074
# 소계    -0.136074  1.000000

# %%
# 인구수와 소계의 상관계수

m_Seoul[['인구수', '소계']].corr()
# Out:
#           인구수        소계
# 인구수  1.000000  0.306342
# 소계   0.306342  1.000000

# %%
m_Seoul.sort_values(by='소계', ascending=False).head(5)
# Out:
#        소계      16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780   159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 양천구  2034  1556.666667  479978.0  475949.0   4029.0  52975.0  0.839413
# 서초구  1930   118.452381  450310.0  445994.0   4316.0  51733.0  0.958451
# 은평구  1873   168.345324  494388.0  489943.0   4445.0  72334.0  0.899091
# 용산구  1624   355.357143  244203.0  229456.0  14747.0  36231.0  6.038828
#
#          고령자비율
# 구별
# 강남구  11.072217
# 양천구  11.036964
# 서초구  11.488308
# 은평구  14.631019
# 용산구  14.836427

# %%
m_Seoul.sort_values(by='인구수', ascending=False).head(5)
# Out:
#        소계     16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 송파구   618  680.882353  667483.0  660584.0   6899.0  72506.0  1.033584
# 강서구   884   44.021739  603772.0  597248.0   6524.0  72548.0  1.080540
# 강남구  2780  159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 노원구  1265  114.412417  569384.0  565565.0   3819.0  71941.0  0.670725
# 관악구  1496  157.179487  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 송파구  10.862599
# 강서구  12.015794
# 강남구  11.072217
# 노원구  12.634883
# 관악구  12.955291

# %% [markdown]
# #  CCTV와 인구현황 그래프로 분석하기

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system.')

# %%
m_Seoul.head()
# Out:
#        소계     16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  243.225806  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  147.826087  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884   44.021739  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  157.179487  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
# '소계' 칼럼을 기준으로 수평 바챠트

m_Seoul['소계'].plot(kind = 'barh', grid = True, figsize = (10, 10));

# %%
# '소계'칼럼을 내림차순 정렬 후 수평 바챠트

m_Seoul.sort_values('소계')['소계'].plot(kind = 'barh', figsize = (10, 10), grid = True);

# %%
# 1인당 CCTV비율 정렬후 수평 바챠트

m_Seoul['1인당 CCTV 비율'] = m_Seoul['소계'] / m_Seoul['인구수'] * 100

m_Seoul.sort_values('1인당 CCTV 비율')['1인당 CCTV 비율'].plot(kind = 'barh', figsize = (10, 10), grid = True);

# %%
# '인구수'와 '소계'의 분포도 그리기

plt.figure(figsize=(6, 6))
m_Seoul.plot(kind = 'scatter', x = '인구수', y = '소계' , s=50)
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(m_Seoul['인구수'], m_Seoul['소계'], 1)
fp1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

# %%
plt.figure(figsize=(10,10))
plt.scatter(m_Seoul['인구수'], m_Seoul['소계'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %% [markdown]
# #  조금더 설득력 있는 자료 만들기

# %%
data_result = m_Seoul

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

data_result['오차'] = np.abs(data_result['소계'] - f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()
# Out:
#        소계      16년 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780   159.589041  570500.0  565550.0   4950.0  63167.0  0.867660
# 송파구   618   680.882353  667483.0  660584.0   6899.0  72506.0  1.033584
# 양천구  2034  1556.666667  479978.0  475949.0   4029.0  52975.0  0.839413
# 서초구  1930   118.452381  450310.0  445994.0   4316.0  51733.0  0.958451
# 용산구  1624   355.357143  244203.0  229456.0  14747.0  36231.0  6.038828
#
#          고령자비율  1인당 CCTV 비율           오차
# 구별
# 강남구  11.072217     0.487292  1388.055355
# 송파구  10.862599     0.092587   900.911312
# 양천구  11.036964     0.423769   760.563512
# 서초구  11.488308     0.428594   695.403794
# 용산구  14.836427     0.665020   659.231690

# %%
plt.figure(figsize=(14,10))
plt.scatter(data_result['인구수'], data_result['소계'], 
            c=data_result['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98, 
             df_sort.index[n], fontsize=15)
    
plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# * 서울시에서 다른 구와 비교했을 때, 강남구, 양천구, 서초구, 은평구는 CCTV가 많지만,
# * 송파구, 강서구, 도봉구, 마포구는 다른 구에 비해 CCTV 비율이 낮다
