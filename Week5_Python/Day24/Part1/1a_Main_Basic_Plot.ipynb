# %% [markdown]
# ## Matplotlib Basic
# ## 20180726
# ## Sungjae Lee

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

X = range(100)
Y = range(100)
plt.plot(X, Y)
# X, Y 데이터로 2차원 선형 그래프를 그린다.

# %%
X = [1,2,3,4]
Y = [1,4,9,16]
plt.plot(X, Y, 'r')
# r 은 red 색상을 지정한 것이다.

# %%
data = np.random.randn(100).cumsum()
plt.plot(data)
# 랜덤한 값으로 선형 그래프를 그린다

# %%
X_1 = range(100)
Y_1 = [np.cos(value) for value in X_1]
# 코사인 값으로 생성한 것

X_2 = range(100)
Y_2 = [np.sin(value) for value in X_2]
# 사인 값으로 생성한 것

plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
# plt.plot(range(100), range(100))
plt.show()

# %%
fig = plt.figure() # figure 반환
fig.set_size_inches(10,10) # 크기지정
ax_1 = fig.add_subplot(1,2,1) # 두개의 plot 생성
ax_2 = fig.add_subplot(1,2,2)  # 두개의 plot 생성

ax_1.plot(X_1, Y_1, c="b")  # 첫번째 plot
ax_2.plot(X_2, Y_2, c="g")  # 두번째 plot
plt.show() # show & flush

# %%
plt.show()

# %%
# 값 설정
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 5
plt.rcParams['lines.color'] = 'b'

# %%
data = np.random.randn(100).cumsum()
plt.plot(data)

# %%
plt.rcParams["figure.figsize"] = (8,5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'

# %%
d1 = np.random.randn(100).cumsum()
d2 = np.random.randn(100).cumsum()

plt.subplot(211)
plt.plot(d1)
plt.subplot(212)
plt.plot(d2, 'r--')

# %%
d1 = np.random.randn(100).cumsum()
d2 = np.random.randn(100).cumsum()

plt.subplot(221)
plt.plot(d1)
plt.subplot(224)
plt.plot(d2, 'r--')

# %% [markdown]
# ### Set color
# - http://matplotlib.org/2.0.2/api/colors_api.html

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

plt.plot(X_1, Y_1, color="#000000")
plt.plot(X_2, Y_2, c="c")

plt.show()

# %% [markdown]
# ### Set linestyle
# - https://matplotlib.org/examples/lines_bars_and_markers/linestyles.html

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")
plt.plot(X_2, Y_2, c="r", ls="dotted")

plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title("Two lines")
plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title('$y = \\frac{ax + b}{test}$')
plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.text(50, 70, "Line_1")
plt.annotate(
    'line_2', xy=(50, 150), xytext=(20, 175),
    arrowprops=dict(facecolor='black', shrink=0.05))

plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True, fancybox=False, loc="upper right")

plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')


plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True, fancybox=True, loc="lower right")


plt.grid(True, lw=0.4, ls="--", c=".90")
plt.xlim(-1000, 2000)
plt.ylim(-1000, 2000)

plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')

plt.grid(True, lw=0.4, ls="--", c=".90")
plt.legend(shadow=True, fancybox=True, loc="lower right")
plt.xlim(-100, 200)
plt.ylim(-200, 200)
plt.savefig("test.png", c="a")
plt.show()

# %%
x = np.linspace(0, 10, 30)
y = np.random.randn(30).cumsum()

plt.subplot(1,2,1)
plt.plot(y, x, 'g*-')

plt.subplot(1,2,2)
plt.plot(x, y, 'r--')

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.1, 0.9, 0.9]) # main
ax2 = fig.add_axes([0.2, 0.5, 0.3, 0.3]) # inner

# main chart
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# inner chart
ax2.plot(x, y, 'g')
ax2.set_title('inner chart')
# Out:
# Text(0.5,1,'inner chart')

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,5), dpi=100)

x = np.arange(0, 10)

axes[0].plot(x, x ** 0.5)
axes[1].plot(x, x ** 1)
axes[2].plot(x, x ** 2)

plt.show()

# %% [markdown]
# ### Scatter

# %%
import numpy as np

data_1 = np.random.randn(512, 2)
print(data_1)
data_2 = np.random.randn(512, 2)
# Out:
# [[ 0.93175493 -0.78864887]
#  [ 0.81235701  2.56941171]
#  [-0.31337534 -0.62875073]
#  ...
#  [ 0.42620886 -0.29481919]
#  [ 0.22774235  0.4696811 ]
#  [-2.02984297 -2.51256362]]

# %%
plt.scatter(data_1[:,0], data_1[:,1], c="b", marker="x")
plt.scatter(data_2[:,0], data_2[:,1], c="r", marker="o")

plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Bar chart

# %%
data = [[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]]

X = np.arange(0,8,2)

# %%
plt.bar(X + 0.00, data[0], color = 'b', width = 0.50)
plt.bar(X + 0.50, data[1], color = 'g', width = 0.50)
plt.bar(X + 1.0, data[2], color = 'r', width = 0.50)
plt.xticks(X+0.50, ("A","B","C", "D"))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

color_list = ['b', 'g', 'r']
data_label = ["A","B","C"]
X = np.arange(data.shape[1])
X
# Out:
# array([0, 1, 2, 3])

# %%
print(data.shape)
# Out:
# (3, 4)

# %%
# data = np.array([[5., 5., 5., 5.],
#         [4., 23., 51., 17],
#         [6., 22., 52., 19]])
# X = np.arange(4)
# for i in range(3):
#     plt.bar(X, data[i], bottom = np.sum(data[:i], axis=0), 
#             color = color_list[i], label=data_label[i])
# plt.legend()
# plt.show()

# %%
A = [5., 30., 45., 22.]
B = [5, 25, 50, 20]

X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'r', bottom = 60)
plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
X = np.arange(4)

plt.barh(X, women_pop, color = 'r')
plt.barh(X, -men_pop, color = 'b')
plt.show()

# %%
X = np.random.randn(1000)
plt.hist(X,bins=100)
plt.show()

# %%
X = np.random.rand(1000)
plt.hist(X,bins=100)
plt.show()

# %%
data = np.random.randn(100,5)
plt.boxplot(data)
plt.show()

# %% [markdown]
# # Pandas Graph

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['font.size'] = 14

# %%
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drinks = pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %% [markdown]
# ## 1. line plot

# %%
drinks[['beer','wine']].plot()

# %%
drinks.plot()

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/ufo.csv'
ufo = pd.read_csv(url)
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
# count the number of ufo reports each year (and sort by year)
ufo.Year.value_counts().sort_index(ascending=False).head()
# Out:
# 2014    5382
# 2013    7003
# 2012    7263
# 2011    5089
# 2010    4154
# Name: Year, dtype: int64

# %%
# compare with line plot
ufo.Year.value_counts().sort_index().plot()

# %%
drinks.continent.value_counts().plot()

# %% [markdown]
# ## 2. Histogram

# %%
drinks.beer.plot(kind='hist', bins = 100)

# %%
drinks.beer.plot(kind='hist', bins=20)
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.title('Histogram of Beer Servings')
plt.savefig('histo.png')

# %%
# compare with density plot (smooth version of a histogram)
drinks.beer.plot(kind='density', xlim=(0, 500))

# %%
# histogram of beer servings grouped by continent
drinks.hist(column='beer', by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11aee17b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b5116d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b53ad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b56b438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b592ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b592b00>]],
#       dtype=object)

# %%
# share the x axes
drinks.hist(column='beer', by='continent', sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b64e5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b716f60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b7ea518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b813a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b845048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b845080>]],
#       dtype=object)

# %% [markdown]
# ## 3. Scatter Plot

# %%
drinks[['beer', 'wine']].sort_values('beer').head()
# Out:
#     beer  wine
# 0      0     0
# 40     0    74
# 79     0     0
# 90     0     0
# 97     0     0

# %%
drinks.plot(kind='scatter', x='beer', y='wine')

# %%
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.2)

# %%
# vary point color by spirit servings
drinks.plot(kind='scatter', x='beer', y='wine', c='spirit', colormap='Blues')

# %% [markdown]
# ## 4. Scatter-Matrix

# %%
pd.scatter_matrix(drinks)
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bbbdef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bdee0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be15748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be3bdd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11be6e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be6e4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bec6208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf84898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bfadf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb3c5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb64c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb98358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cbbe9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cbf00b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cc16710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cc3fda0>]],
#       dtype=object)

# %%
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']])
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cda8780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cdceef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ce97550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cec0be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ceef2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ceef2e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf41fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf716a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf9ad30>]],
#       dtype=object)

# %%
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(5, 4))
# Out:
# /Users/sungjae/y36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d31c0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3af160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3d47f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d47de80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d4af550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d4af588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5072b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d530940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d55afd0>]],
#       dtype=object)

# %% [markdown]
# ## 5. Bar Plot

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().plot(kind='bar')

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
# side-by-side bar plots
drinks.groupby('continent').mean().plot(kind='bar')

# %%
# drop the liters column
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %%
drinks.spirit.sort_values().head()
# Out:
# 0      0
# 27     0
# 128    0
# 118    0
# 111    0
# Name: spirit, dtype: int64

# %%
drink_country = drinks[['beer', 'wine']].sum(axis=1)
drink_country.index=drinks.country
drink_country10 = drink_country.sort_values(ascending=False)[:10]
drink_country10.plot(kind='bar')

# %% [markdown]
# ## 6. Box-Plot

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks.plot(kind='box')

# %%
drinks.spirit.plot(kind='box')

# %%
# box plot of beer servings grouped by continent
drinks.boxplot(column='beer', by='continent')

# %%
# box plot of all numeric columns grouped by continent
drinks.boxplot(by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1df88ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e063f60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e096390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e0bf780>]],
#       dtype=object)

# %% [markdown]
# ## Saving a Plot

# %%
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram_original.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

plt.show()

# %%
from __future__ import print_function

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
import time


def generate(X, Y, phi):
    '''
    Generates Z data for the points in the X, Y meshgrid and parameter phi.
    '''
    R = 1 - np.sqrt(X**2 + Y**2)
    return np.cos(2 * np.pi * X + phi) * R


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make the X, Y meshgrid.
xs = np.linspace(-1, 1, 50)
ys = np.linspace(-1, 1, 50)
X, Y = np.meshgrid(xs, ys)

# Set the z axis limits so they aren't recalculated each frame.
ax.set_zlim(-1, 1)

# Begin plotting.
wframe = None
tstart = time.time()
for phi in np.linspace(0, 180. / np.pi, 100):
    # If a line collection is already remove it before drawing.
    if wframe:
        ax.collections.remove(wframe)

    # Plot the new wireframe and pause briefly before continuing.
    Z = generate(X, Y, phi)
    wframe = ax.plot_wireframe(X, Y, Z, rstride=2, cstride=2)
    plt.pause(.0001)

print('Average FPS: %f' % (100 / (time.time() - tstart)))
# Out:
# Average FPS: 155.478189
