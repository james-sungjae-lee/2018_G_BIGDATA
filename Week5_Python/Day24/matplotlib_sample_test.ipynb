# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.arange(1,10)
y = x*5

# %%
x = np.arange(1,10)
y = x^4

# %%
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
x = np.arange(1, 10, 0.1)
y = x*0.2
y2 = np.sin(x)

# %%
plt.show()

# %%
x = np.arange(1,10)
y = x*5


plt.show()

# %%
x=np.arange(1,10)
y1 = x*5
y2 = x*1
y3 = x*0.3
y4 = x*0.2




plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
plt.figure(figsize=(20,5))

plt.show()
